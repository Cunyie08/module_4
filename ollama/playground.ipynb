# %%
# !pip install ollama

# %%
import ollama

# %%
response = ollama.chat(
    model= "gemma3:1b",
    message = [
    {"role": "user", "content":"How to make pancakes in 100 words"}
    ]
)

print(response["message"]["content"])
